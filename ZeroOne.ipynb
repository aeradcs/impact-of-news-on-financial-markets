# %%
#Import the libraries we’ll be using throughout our notebook:
import pandas as pd
import numpy as np
import csv
import math
import pandas as pd
from nltk.corpus import stopwords as nltk_stopwords
from gensim.models.hdpmodel import HdpModel
from gensim.corpora import Dictionary
import re
import plotly.express as px
import gensim.matutils as matutils
from sklearn.decomposition import SparsePCA
from sklearn import metrics
from sklearn.ensemble import RandomForestClassifier
# Out:
# /Applications/Anaconda/anaconda3/lib/python3.8/site-packages/gensim/similarities/__init__.py:15: UserWarning: The gensim.similarities.levenshtein submodule is disabled, because the optional Levenshtein package <https://pypi.org/project/python-Levenshtein/> is unavailable. Install Levenhstein (e.g. `pip install python-Levenshtein`) to suppress this warning.
#   warnings.warn(msg)

# %%
#Text Cleaning and Preprocessing
def preprocessing(text):
    stops = nltk_stopwords.words('english')

    text = text.lower()

    # remove emails
    text = re.sub('\S*@\S*\s?', ' ', text)

    # remove numbers and dates
    text = re.sub('\$?[0-9]+[\.]?[0-9]*s?%?\$?\s?', ' ', text)

    # remove hastags
    text = re.sub('#\S*\s?', ' ', text)

    # remove https
    text = re.sub('https://\S*\s?', ' ', text)

    # remove http
    text = re.sub('http://\S*\s?', ' ', text)

    for x in [",", ":", "!", "?", ";", "[", "]",
              "(", ")", "\"", "\'", ".", "\"",
              "#", "@", "&", "`", "'", "’", "-",
              "+", "=", "_", "<", ">", "\\",
              "|", "}", "{", "/", "—", "$", "“", "”"]:
        text = text.replace(x, "")
    text = text.split()
    cleaned_text = []
    for word in text:
        if not (word in stops):
            cleaned_text.append(word)
    text = cleaned_text
    return text

# %%
#Read and Inspect the Data
news = pd.read_csv('yahoo_finance_marked_df.csv')

# %%
news
# Out:
#       mark        date                                               news
# 0        0  2021-10-01  TAIPEI, Oct 1 (Reuters) - Resolving the global...
# 1        0  2021-10-01  (Bloomberg) -- Asian stocks and U.S. futures s...
# 2        0  2021-10-01  TOKYO, Oct 1 (Reuters) - Japanese shares tumbl...
# 3        0  2021-10-01  By Sonali PaulMELBOURNE (Reuters) - Oil prices...
# 4        0  2021-10-01  By Kevin BucklandTOKYO (Reuters) - Asian equit...
# ...    ...         ...                                                ...
# 1377     0  2021-09-17  Anastasia Amoroso, iCapital Network Chief Inve...
# 1378     0  2021-09-15  The Bank of England expects inflation to hit 4...
# 1379     0  2021-09-14  The major Asia-Pacific stock indexes traded mi...
# 1380     0  2021-09-14  (Bloomberg) -- Japanese stocks advanced for a ...
# 1381     0  2021-09-13  Financial stock and mining firms were leading ...
#
# [1382 rows x 3 columns]

# %%
df = news.copy()
df['news'] = df['news'].apply(lambda text: preprocessing(text))
print(df.head())
# Out:
#    mark        date                                               news
# 0     0  2021-10-01  [taipei, oct, reuters, resolving, global, shor...
# 1     0  2021-10-01  [bloomberg, asian, stocks, us, futures, starte...
# 2     0  2021-10-01  [tokyo, oct, reuters, japanese, shares, tumble...
# 3     0  2021-10-01  [sonali, paulmelbourne, reuters, oil, prices, ...
# 4     0  2021-10-01  [kevin, bucklandtokyo, reuters, asian, equitie...

# %%
df['news']
# Out:
# 0       [taipei, oct, reuters, resolving, global, shor...
# 1       [bloomberg, asian, stocks, us, futures, starte...
# 2       [tokyo, oct, reuters, japanese, shares, tumble...
# 3       [sonali, paulmelbourne, reuters, oil, prices, ...
# 4       [kevin, bucklandtokyo, reuters, asian, equitie...
#                               ...
# 1377    [anastasia, amoroso, icapital, network, chief,...
# 1378    [bank, england, expects, inflation, hit, end, ...
# 1379    [major, asiapacific, stock, indexes, traded, m...
# 1380    [bloomberg, japanese, stocks, advanced, third,...
# 1381    [financial, stock, mining, firms, leading, gai...
# Name: news, Length: 1382, dtype: object

# %%
NER = pd.read_csv('yahoo_NER.csv')

# %%
NER['name']
# Out:
# 0              TAIPEI
# 1            Malaysia
# 2            COVID-19
# 3              Taiwan
# 4        Wang Mei-hua
#              ...
# 69468           Oanda
# 69469           Asian
# 69470     Wall Street
# 69471         Chanthu
# 69472        Shanghai
# Name: name, Length: 69473, dtype: object

# %%
NERnorm = set(NER['name'])

# %%
NERnorm
# Out:
# {'Naeem Aslam',
#  'Sorare',
#  'Aston Martin DB4 GT Zagato Coupe',
#  'Jacob Frey.',
#  'Bruces',
#  'Avastin',
#  'Naked Brand Group',
#  'Secret Service',
#  'Transportation Security Administration',
#  'Craig-Hallum',
#  'BNB Cash',
#  'October.Mark Wahlberg',
#  'LCpl Hunter Clark',
#  'Q & A go',
#  'level.Exxon Mobil',
#  'Esther Choo',
#  'Bremmer',
#  'Do Kwon',
#  "dollars'Healthcare",
#  'Kristoffer Kjær Lomholt',
#  'Valencia',
#  'Build it Back Better',
#  'Chipotle Mexican Grill',
#  "Glimmer of hope'Grayscale",
#  'Kelton J. Cochran',
#  'John McCain',
#  'Stemmle',
#  'Switzerland-based',
#  'Qdoba',
#  'Ammann',
#  'Ashish Jha',
#  'rules.Sheila Bair',
#  'Department for Education',
#  'Natasha Bhuyan.',
#  'SBEC',
#  'Sears Home Services',
#  'Oliver Daemen',
#  'Daily Beast',
#  'Sens',
#  'Coinbase Cloud',
#  'service.Sheila Bair',
#  'Salvador',
#  'FTSE 250',
#  'LabCorp',
#  'Canadian',
#  'Del Rio',
#  'Jovan Vavic',
#  'LUNAtics',
#  'Bowery Hotel',
#  'Romney',
#  'Wharton',
#  'Toby Chopra',
#  'Ipsos',
#  'Jared',
#  'Gumbinger',
#  'Jason Redmond',
#  'Shiba Inu',
#  'Embry-Riddle',
#  'UAL',
#  'Chainanalysis',
#  'JTC',
#  'Zacks.com',
#  'Mickie',
#  'Record App Activity',
#  'The 73rd Primetime Emmy Awards',
#  'DEO',
#  'U.S.How',
#  'Philippines',
#  'Diane Jaffee',
#  'Kernan.',
#  'Steve Mnuchin',
#  'Woodstock of Capitalism post-Buffett',
#  'Business Roundtable',
#  'Smead Capital Management',
#  'Banza Pizza',
#  'Cleveland-Marshall College of Law',
#  'Eric',
#  'United States.Aero Engine Corp',
#  'Laurence Tribe',
#  'How to Value a Business',
#  'Nikkei Asia',
#  'PATRICK T. FALLON',
#  'Binky Chadha',
#  'Yahoo Finance US',
#  'Sling TV',
#  'SAN FRANCISCO',
#  'Refinitiv',
#  'JP Morgan Chase & Co.',
#  'PT.Alexandra',
#  'Yahoo FinanceBanks',
#  'Benzinga.com',
#  'Switzerland',
#  'eBay',
#  'Benchmark European',
#  'Jubilee Vape & Smoke Inc.',
#  'DCEP',
#  'Ida-like',
#  'YouTubeAlexis Keenan',
#  'Governor Baker',
#  'UPS',
#  'Sheremetyevo',
#  'Deepfakes',
#  'Pam Mitchell',
#  'Chanin',
#  'ReggieBush',
#  'Clifford',
#  'Poloniex',
#  'Karim Hijazi',
#  'Morristown Medical Center',
#  'Oppenheimer',
#  'Morehouse College',
#  'Baski',
#  'Gulf of Mexico',
#  'Kyle Van Winkle',
#  'Singer',
#  'CHRISTOPHER WALLER',
#  'Pericles',
#  'Rubin',
#  'FOUR',
#  'Eswar Prasad',
#  'Crypto.com',
#  'Johannes Stroebel',
#  'Afghanistan.',
#  'Myers',
#  'Cleveland Clinic',
#  'Manila',
#  'David',
#  'Jerry Nadler',
#  'LTC',
#  'WalmartInc',
#  'Senate',
#  'Dan Warmenhoven',
#  "Yung-Yu.We've",
#  'Mittelstand',
#  'Trulia',
#  'Paul Schatz',
#  'Golden Gate Bridge',
#  'U.S. Dollar',
#  'Department of Treasury',
#  'National Governors Association Summer Meeting',
#  'Paycheck Protection Program Extension Act of 2021',
#  'Australia.',
#  'National Federation of Independent Businesses',
#  'Lome',
#  'Mike SegarIn',
#  'BMW i8',
#  'Derrick Palmer',
#  'Alabamians',
#  'LGBTQ',
#  'Mathieu Lewis-Rolland',
#  'CBS News.Vanessa Prado',
#  'Cal Athletics',
#  'Coca Cola',
#  'Amazaon',
#  'Altieri',
#  'Ethereum-like',
#  'non-THC',
#  'Leslie Adler',
#  'University of Memphis',
#  'Gilead Sciences',
#  'Sundial',
#  'COVID-19Greta Thunberg',
#  'before’Christina Gibbs',
#  "Atlantic.Disney's",
#  'U.S. State Department',
#  '2019.Susan Neely',
#  'Ferrari 340',
#  'NBA Academies',
#  'Russian Presidential Press and Information Office',
#  'riskSonders',
#  'House Ways and Means committee',
#  'Energy Information Administration',
#  'NATO',
#  'Labor Secretary.Union',
#  'Sekinger',
#  'Croslite ™',
#  'South Korea',
#  'TSM',
#  'Merkel',
#  'Geneva',
#  'Stems Floral',
#  'Maryland.',
#  'Axios’ Sam Ro',
#  'Department of Interior',
#  'GlobalData',
#  'Saigon',
#  'PRA',
#  'Michael Pachter',
#  'Hurricane Alley',
#  'The Lancet',
#  'United States.The',
#  'gains.Yahoo Finance',
#  'Joffe.',
#  'John Davison Rockefeller',
#  'AvaTrade',
#  'FedEx',
#  'L.A. County',
#  'Mat Ishbia',
#  'Warner Media',
#  'Caplan',
#  'Miami.Erik Voorhees',
#  'Anna-Sophia Tutton',
#  'Kiddos',
#  'WikiLeaksPelosi',
#  'Lordstown',
#  'Buy',
#  'Katam Hill',
#  'Asian American',
#  'Wells Fargo Securities',
#  'Matt Jelonek',
#  'Miye Oni',
#  'Dominic Lipinski',
#  'China Declares Cryptocurrency Transactions Illegal',
#  'Chattanooga',
#  'Jack',
#  'Ripiert',
#  'Joel Lerner',
#  'Margaret O’Mara',
#  'Long',
#  'Shenandoah',
#  'Lancet',
#  'Ivan Pierre AguirreMeanwhile',
#  'Grand Teton',
#  'The Delta',
#  'Crimea',
#  'Bitcoin Day AheadBitcoin',
#  'Department of Defense',
#  'assertions.Russian',
#  'Green Party',
#  'Comcast Business Tour',
#  '4K Max',
#  'Viktor Yanukovych',
#  'Bly',
#  'Enlivant',
#  'Coronavirus Aid',
#  'Costfoto',
#  'Inglewood',
#  'Research Affiliates',
#  'post-GFC',
#  'Wally Funk',
#  'SHREVEPORT',
#  'Andrew Boyd',
#  'Wayne Couzens',
#  'Yahoo Finance UK',
#  'Kena Betancur',
#  'Bank CEOsSanders',
#  'Reserve Tanker Fleet',
#  'Noel Holmes',
#  'Andy Barr',
#  'U.S.',
#  'Scott',
#  'Sky',
#  'Mission Impossible',
#  'Singapore.Federal Reserve',
#  'Kraft-Heinz',
#  "Pebble Beach Concours d'Elegance",
#  'The Loonie Gains Traction Following Greenback SurgeThe Crypto Daily – Movers and Shakers',
#  'dyslexia.O’Leary’s',
#  'Getty ImagesThe',
#  'Ala',
#  'Health Solutions',
#  'addressed.Michelle Eisen',
#  'Yahoo Finance.Hence',
#  'Miramar MCAs',
#  'Arkansas House',
#  'U.S. Justice Department',
#  'Hubei',
#  'Ninth Circuit',
#  'Soviet',
#  'Federal Reserve.So',
#  'White House Task Force',
#  'Los Angeles Times',
#  'Valley of Hype : The Culture that Built Elizabeth Holmes',
#  'Warmenhoven',
#  'Visa',
#  'Goldman.Once',
#  'Land Betterment',
#  'City University of New York',
#  'Saint Laurent',
#  'Grand Duke Kirill Vladimirovich',
#  'National Institute of Health',
#  'Norman Maclean',
#  'Cameron Bure',
#  'Philadelphia Fed',
#  'CW',
#  'Zume',
#  'Upper West Side',
#  'Formula 1',
#  'Cape Coral',
#  'Election Day',
#  'Small Business Optimism Index',
#  'Nike Flyprint',
#  'Mt. Gox',
#  'Ariana Grande',
#  'Jacobson.',
#  'Rogozinski',
#  'Mayén.By',
#  'Business Insider DeSantis',
#  'Kayleigh McEnany',
#  'GM China JVsat',
#  'San Francisco-Oakland-Berkeley',
#  'Aspen Ideas Festival.The',
#  'Sanders’ Facebook',
#  'Dreamforce',
#  'Obamacare',
#  'Douglas Elliman',
#  'Meat Chicken Tenders',
#  'Rosenthal.Story',
#  'Stephan WinkelmannSo',
#  'School of Management and Labor Relations',
#  'says.Nicholas Bloom',
#  'Daytona Beach',
#  'Northwest',
#  'Rutgers School of Management and Labor Relations',
#  'Dick ’s Sporting Goods',
#  'Otto-Uber',
#  'reddit Robinhood',
#  'Dave Ashton',
#  'Hathaway',
#  'Adriana',
#  'Outer Metropolitan',
#  'NASDAQ',
#  'Anastasia',
#  'Brooke DiPalma',
#  'School of Human Resources and Labor Relations',
#  'Dolby Vision HDR',
#  'Elmhurst Hospital Center',
#  'UBiome',
#  'Cryptocurrency reporterDavid Hollerith',
#  'Kissinger',
#  'Swawn',
#  'Citadel Securities',
#  'de la Casa Blanca',
#  'Jim Farley',
#  'Jim Lo Scalzo',
#  'Vishal Joshi',
#  'Shang Chi',
#  'Brian McCarthy',
#  'SECOn',
#  'Surface Pro 8',
#  'Microsoft Surface Book',
#  'Ministry',
#  'Federal',
#  'Leaver and a Remainer',
#  'Digiconomist',
#  'Fortune Global Forum',
#  'SXSW Music , Film + Interactive Festival',
#  'Purchasing Managers Index',
#  'Tencent Holdings Ltd.',
#  'CBS News.Jennifer Schonberger',
#  'Orca Capital',
#  'U.S.I',
#  'Lalonde',
#  'West Haven Child Development Center',
#  'IAG',
#  'Sonnenshein',
#  'Jocelyn Bailey',
#  'Leonore Elle Hawkins',
#  'PixelSense',
#  'SNL',
#  'Chile',
#  'Jack-O Pumpkin Ale',
#  'PBC',
#  'The Broadway League.Story',
#  'Michelle McKissack',
#  'Frederica Wilson',
#  'Dan Kildee',
#  'The Northern Trust',
#  'Steven James',
#  'Granite State',
#  'Mona Amin',
#  "Georgette Bukalam O'Leary",
#  'Aggarwal',
#  'Sen',
#  'Monterey.Magers',
#  'Capitol Visitor Center',
#  'Black Americans',
#  'Institute for Health Metrics and Evaluation',
#  '2012.SAN FRANCISCO',
#  'Community Investment Fund',
#  'Macs',
#  'Mercedes-Benz USA',
#  'GETTY',
#  'CAMimage',
#  'LVMH',
#  'ETF.Raj',
#  "Grubb 's Pharmacy",
#  "SunDial Capital Research.Mehta's",
#  'Walter Olson',
#  'Story continuesChertavian',
#  'Occupational Safety and Health and Act of 1970',
#  'carminesnyc.com',
#  'Suzuki',
#  'effect.Brian Cheung',
#  'Tankan',
#  'Henny Ray ABRAMSCan',
#  'SAUL LOEB',
#  'Chainalysis data.David Hollerith',
#  'ATM',
#  'Brands International Inc',
#  'Fatal Encounters',
#  'Aaron Rogers',
#  'Groundhog Day',
#  'Guzman',
#  'Delyanne',
#  'Christmas rushSainsbury',
#  'Philly Fed',
#  'National Football League',
#  'Bobby Scott',
#  'Leonardo Rufino',
#  'St. Ives',
#  'Level 5',
#  'Ussher',
#  'ASAP.',
#  'Ranney',
#  'Korean',
#  'Wilson Road',
#  'Oxford Nanopore',
#  'reddit LinkedIn',
#  'Internal Revenue Service',
#  "O'Brien",
#  'Food Bank for NYC',
#  'Brent',
#  'McDonough School of Business',
#  'Chicago',
#  'Evolve ETFs',
#  'EQS',
#  'NGI',
#  'kidsWarren Buffett',
#  'Vampire Diaries.',
#  'Scripps Research Translational Institute',
#  'Joros',
#  'James Todd Smith',
#  'LinkedIn.Max Zahn',
#  'San Francisco Bay Area',
#  'AsiaObama',
#  'Brauer',
#  'Montagues',
#  'Travis Kling',
#  'Quest Psychology Services',
#  'Oanda',
#  'Keith Gill',
#  'Main Street.They',
#  'Joth Ricci',
#  'Jonathan Katz',
#  'Duo',
#  'Cordi O’Hara',
#  'FreeBritney Rally',
#  'state.University of Georgia',
#  'Christmas.Nicola Sturgeon',
#  'hereHolmes’',
#  'review.Philip Morris',
#  'Section 232',
#  'Patrick McMullan',
#  'Jan 6th committee',
#  'Exodus',
#  'OREOs',
#  'National Restaurant Association',
#  'Fauci',
#  'Bezos-backed',
#  'Sun Country',
#  'Mario Tama',
#  '4xe Rubicon',
#  'The City College of New York',
#  'FY22',
#  'James Bathgate',
#  'Eurosystem',
#  'Committees',
#  '2021Jack DorseyFrom',
#  'Savanthi Syth',
#  'John Hodulik',
#  'Eileen Cassidy Rivera',
#  'Netflix Reed Hastings',
#  'Amazon Web Services',
#  'DataSouth Korean',
#  'Blockware Solutions.Clemente',
#  'John Murphy',
#  'Ryan Losi',
#  'The Art Of The Exit In all',
#  'Jonas',
#  'Thomas KingsleyPolice',
#  'The Re-Opening Night of " Wicked',
#  'Eccles',
#  'Conservative',
#  'OR',
#  'Homer',
#  'Eisen',
#  'fired.Metropolitan Transportation Authority',
#  'Jennifer Schonberger',
#  'Kernan',
#  'National Small Business Week',
#  'Wingstop',
#  'South by Southwest',
#  'Drew Angerer',
#  "Whole Woman 's Health",
#  'Yahoo Finance.Aside',
#  'Brian Kemp',
#  'Free Exercise Clause',
#  'Utah Jazz',
#  "The Brother 's Bond BourbonSomerhalder",
#  'Evergrande royal',
#  'San Salvador',
#  'Consumer Sentiment',
#  'Anne Spalding',
#  'California Bureau for Private Postsecondary Education',
#  'Yahoo Finance.Read',
#  'Birmingham Division of Infectious Diseases',
#  'Queen ’s Medical Centre',
#  'Lynnfield',
#  'Stanford University ’s Graduate School of Business',
#  'ULSD',
#  'Getty Images',
#  'Story continuesVanderbilt',
#  "Ajshaps'If",
#  'Selma Hepp',
#  'Suozzi',
#  'CSCO',
#  'David Bahnsen',
#  'West Africa',
#  'National Macaroni',
#  'Johnson & Johnson ( J & J',
#  'consumers.NEW YORK',
#  'Robert Greenstein',
#  'now.Yahoo Finance HighlightsChina',
#  'FDA',
#  'Wolfpack Research',
#  'Stavanger',
#  'Basel II',
#  'Ileen Devault',
#  'Bruces’',
#  'Citigroup ( C',
#  'McRib Season.’',
#  'Baffa',
#  'Wamsi Mohan',
#  'YUM',
#  'Ferrari',
#  'RM Sotheby',
#  'Scripps Research Institute',
#  'CVX',
#  'Sun Group Wealth Partners',
#  'MichaelBKelleyRead',
#  'Mercer County',
#  'Friday.Kansas City Fed',
#  'Downing Street',
#  'M25',
#  'Zach Pandl',
#  'Buddy Carter',
#  'Coinbase Global Inc.',
#  'TRX',
#  'CVS Health',
#  'Li Xin',
#  'Flow Blockchain',
#  'Rockdale',
#  'Ralph Whitworth',
#  'normal’XFL',
#  'Southern California',
#  'Emily Gee',
#  'Jacques Slade',
#  'coal.Steag GmbH',
#  'Emily Hill',
#  'Google News',
#  'Kevin LamarqueAs Beijing',
#  'The Shed',
#  'Timothy Chubb',
#  'El-Erian',
#  'Atlantic',
#  'Charles Schumer',
#  'Scott Olson',
#  'Christoph Bajewski',
#  'Dow Jones',
#  'herePlaintiffs',
#  'Tiger King’',
#  'Indianapolis',
#  'The Code',
#  'Valera Golovniov',
#  'MINNESOTA',
#  'Ben Madick',
#  'Royal Perks ”',
#  'unit.Gree',
#  'CarMax',
#  'Floridians’',
#  'CI Galaxy Ethereum ETF',
#  'Nikola',
#  'employeesLos Angeles',
#  'release.Brooke DiPalma',
#  'IoD Directors’ Economic Confidence Index',
#  'Lewis & Clark Law School',
#  'MacKenzie Bezos',
#  'McKinsey & Co.',
#  'Indiana University',
#  'Max Zahn',
#  'Federal ReserveA Fed',
#  'J & J',
#  'REUTERSDemocrats',
#  'Bannister',
#  'Jimmy Carter',
#  'Theresa May',
#  'Baker Botts.A',
#  'Peter Essele',
#  'Mike Gilmartin',
#  'Lil Nas X',
#  'D. Taylor',
#  'Stephanie Ruhle',
#  'Gerry Doyle',
#  'Excelsior Pass',
#  'U.S. Public Health Service Commissioned Corps',
#  'Nets',
#  'LVMUY',
#  'White House’While',
#  'Jefferies Analyst',
#  'Zhumadian',
#  'Kathy Donnelly',
#  'ISA',
#  'Taco Bell Defy',
#  'John Lynch',
#  'Eureka',
#  'Cynthia Cox',
#  '2019 New York Times Dealbook',
#  'We Found Love',
#  'The Rise of the Sister Cities',
#  'AMSainsbury',
#  'Milk Bar Pie',
#  'Alex Mashinsky',
#  'BJ Restaurants',
#  'Ben Affleck',
#  'NBS Non-Manufacturing PMI',
#  'DC',
#  'State of the Union',
#  'Social SecurityThree-quarters',
#  'Lin-Manuel Miranda',
#  'Nancy Hinkle.',
#  'The Boeing Company BA',
#  'SPD',
#  'Rivan',
#  'Dream Air',
#  'JB Milliken',
#  'Nader',
#  'Neustar',
#  'Higher Education Act',
#  'ESLR',
#  'Corvette',
#  'Arrowhead Stadium',
#  'Dominican',
#  'post-Cold War',
#  'Vicki Behringer',
#  'LOLMedicare',
#  'Treasury Department.Households',
#  'AkikoFujitaFirst Solar',
#  'SMCCF',
#  'ETF Research Reports Coinbase Global , Inc',
#  'Apple Watch SE',
#  'defenses.Amazon',
#  'Twisted Tea',
#  'Bolt Digital',
#  'Raymond James',
#  'Chai',
#  'Ayanna Pressley',
#  'hereOne',
#  'Alan Schnitzer',
#  'New Hampshire',
#  'Unite Here',
#  'Trump.From',
#  'Vicki BehringerApple',
#  'Money Tomorrow',
#  'Labour MPAllowing',
#  'UNITED STATES',
#  'MS',
#  'Subcommittee',
#  'Seattle.Story',
#  'American Relief Plan',
#  'Suzanne Antolini',
#  'Cold War',
#  'lowsBritish',
#  'Wood',
#  'Alaska',
#  'Emerson CollectiveRon Conway',
#  'Nielsen',
#  'MassMutual',
#  'Business Insider',
#  'Dell',
#  'Apps',
#  'battle.David Baffa',
#  'Joe Ingles',
#  'Amazon Project',
#  'View',
#  'Sunny',
#  'Energy Aspects',
#  'Betsy DeVos',
#  'Kiplinger',
#  'Lincoln Eccles',
#  'Biden Administration',
#  'China Evergrande Group',
#  'AAA CLO',
#  'Sigh',
#  'Pad 39A',
#  'Rick Singer',
#  'Edison ” analyzer',
#  'American Dream',
#  'SARS-CoV-2',
#  'Mark Dahncke',
#  'David Chatel',
#  'Nick OxfordLearning',
#  'House Foreign Affairs Committee',
#  'American Media Inc',
#  'Small Business Administration',
#  'Jonathan Athow',
#  'Lisbon',
#  'Ray McGovern',
#  'TSPU',
#  'Better Business Bureau',
#  'Beth Hurvitz',
#  'Sylvester',
#  'Marta Lavandier',
#  'Medium',
#  'Coronavirus Response',
#  'Gunn',
#  'Thomas KingsleyThere',
#  'UM Capital Region Medical Center',
#  'Ryan Lance',
#  'S-1',
#  'Federal Reserve Act',
#  '1033',
#  'IntegraCareFacebook',
#  'Beijing',
#  'Sean Hannity.',
#  'Joro',
#  'Sequoia',
#  'Stanford University',
#  'Adidas',
#  'Kabul Airport',
#  'Student Debt Crisis Center',
#  'LAUSD',
#  'Thursday.Senate',
#  'Sheila Dang',
#  'University of Pennsylvania',
#  'Rob Falzon',
#  'City of Minneapolis',
#  'Jen Psaki',
#  'Pomp',
#  'University of Indiana.Starting',
#  'Morens',
#  'AMZN',
#  'Hamblin',
#  'abortionPelosi',
#  'National Consumer Law Center',
#  'TURKEY',
#  'StrategistCongress',
#  'Reid HoffmanKohl',
#  'National Anthem',
#  'NIKE , Inc',
#  'LCID',
#  'Justin Baragona',
#  'Pokémon Trading Card Game',
#  'Cincinnati',
#  'ADA',
#  'mid-week.Federal Reserve',
#  'Qualcomm-powered',
#  'Girotra. “ M & A',
#  'AFG',
#  'Rosengren',
#  'Bourla',
#  'Coinbase',
#  'Jeremy Bloom',
#  'Alan Greenspan',
#  'U.S. Chamber of Commerce',
#  'Task Force on Climate-Related Financial Disclosures',
#  'Dennis Van Tine',
#  'The Purge',
#  'Turner',
#  'Grain Millers International Union',
#  'CNBC.The',
#  'Interstate',
#  'Franklin',
#  'Maryland',
#  'Graham',
#  'Vote Union Yes !"',
#  'Center on Poverty and Social Policy',
#  'Orman',
#  'WonderFi',
#  'Federal Reserve Board of Governors',
#  'Nick Juhle',
#  'Hindenburg Omen',
#  'HDR10',
#  'Ian Somerhalder',
#  'Raytown',
#  'Fraser Nelson.They',
#  'Hospital de Clinicas',
#  'Tread and Tread +',
#  'Syngal',
#  'TASS',
#  'Wi-Fi',
#  'Subaru WRX.Consider',
#  'Collision of Power : Trump',
#  'Mohammed bin Salman',
#  'Addison',
#  'Norway',
#  'Final Round',
#  'Montero',
#  'John Locher',
#  'Neymar',
#  'Colin Nabity',
#  'Bessemer',
#  'ZM',
#  "New Silk Road'Biden",
#  'Yvonne Gonzalez Rogers',
#  'FIMA',
#  'Whole Foods.After',
#  'Donnelly.Try Yahoo Finance Plus',
#  'AnjKhemRead',
#  'Osmosis',
#  'Raup',
#  'Team Trump',
#  'Manisha Girotra',
#  'United States',
#  'Steve [ Wozniak',
#  'Miles',
#  'Getty Images for Watermark Conference for Women',
#  'Fluent Research',
#  'Georgians',
#  'Obama',
#  'Kathryn McLay',
#  'Evergrande.',
#  'Hobbs',
#  'R-FL',
#  'Liev Schreiber',
#  'Mystique',
#  'Defense Department',
#  'eMarketer',
#  'Manhattan Venture',
#  'T-Mobile',
#  'Story continuesGregory Hayes',
#  'YouTube.Higher',
#  'Onvansertib',
#  'Will Clemente',
#  'CMD-ZZZ.',
#  'Mich',
#  'STMicroelectronics',
#  'Lempira',
#  'Porsche 917k',
#  'Sarah Everard.He',
#  'Trump World Tower',
#  'APA',
#  'ExxonMobil',
#  'Yahoo Finance Live.Kelly',
#  'Artyom Geodakyan',
#  'Stephanie',
#  'King.Whinstone',
#  'François-Henri Pinault',
#  'Fortnite',
#  'Indian',
#  'Emily',
#  'Papua New Guinea',
#  'Jacobson',
#  'Richard Branson',
#  'Natural Gas Intelligence',
#  'Appelbaum.',
#  'Kingdee International',
#  'Sipher',
#  'MADRID',
#  'Jessica Roth',
#  'Anessa',
#  'Richard Rogers Theatre',
#  'Amanda Andrade-Rhoades',
#  'Hulu',
#  'Montecito',
#  'Zhao',
#  'LTE',
#  'Winklevoss',
#  'East Anglia',
#  'Bassett',
#  'Steptoe & Johnson LLP',
#  'Larry Adams',
#  'ProcureAM',
#  'them.Social SecuritySocial Security',
#  'App Store.',
#  'Randy Carver',
#  'Eric Garcetti',
#  'BTCC-U.TO',
#  'Rick Hoebeke',
#  'BCTGM',
#  'Eric Feferberg',
#  'CARES',
#  'LeBron James',
#  'Mortgage Banker Association',
#  'Mark Lennihan',
#  'CMS',
#  'F',
#  'Wario',
#  'Broadband',
#  'Godon Balmer',
#  'Ponzi',
#  'Metropolitan',
#  'Taryn Byron',
#  'REUTERS / Mike SegarCEO',
#  'Ben Wizner',
#  'Matt Maley',
#  "Bureau of Economic Analysis'",
#  'Geico',
#  'reddit Job',
#  'Berglund.Here’s',
#  'Muslim',
#  'Moldova',
#  'SHAK',
#  'Pablo Sanchez',
#  'revealed.OAKLAND',
#  'GettyAs',
#  'CaitlinLong',
#  'Anhui Province',
#  'data.FDA',
#  'Raissa Kasolowsky',
#  'play.PetroChina Co . Ltd',
#  'Schurman',
#  'USA.Video Transcript',
#  'worldWe',
#  'exchange.NEW YORK',
#  'Nasdaq MarketSite jumbotron',
#  'CEOVantage Group Holdings',
#  'Aston Martin DBX SUV',
#  'Bruce Isackson',
#  'MSNLF',
#  'Larry Bloom',
#  'Southeast Asia',
#  'Michael Barasch',
#  'Bay Area',
#  'National Association of Medical Examiners',
#  'Peter NurseInvesting.com',
#  'Wizner',
#  "solve'McGregor",
#  'Pressure Mounts in LondonBitcoin',
#  'Parets.Gold',
#  'Realtor.com',
#  'Josh Goodbody',
#  'MyPillow',
#  'Kraken Security Labs',
#  'Dallas Fed',
#  'C.R. Bard',
#  'Northern California',
#  'tooJeff Bezos',
#  'Lockheed Martin',
#  'Collin Plume',
#  'Air Jordan',
#  'Howley',
#  'Zach',
#  'Wynn',
#  'redditRead',
#  'Mr. Balwani',
#  "Problem Solvers : Compensating College Athletes for Their Likeness'",
#  'Alex Yao',
#  'The Century Foundation',
#  'Schulz',
#  'Federal Trade Commission',
#  'employees.Delta',
#  'U.S. Chamber of Commerce.Raimondo',
#  'KSS',
#  'Barclays',
#  'Steve Colon',
#  'Guaranty Agencies',
#  'Houston Food Bank',
#  'AJ Bell',
#  'Bhutan',
#  'AltFinance',
#  'BNPL',
#  'Old Mutual Investment Group',
#  'Truvian Sciences',
#  'John M Phillips',
#  'MercadoLibre',
#  'Pressley',
#  'Nicaragua',
#  'PetroChina Co . Ltd .',
#  'Kiwi Dollar',
#  'Canopy Growth',
#  'Pat Toomey',
#  'Harriet',
#  'Yahoo Finance Live.A',
#  'Brendan Ahern',
#  'Western Hemisphere',
#  'Richard Nicholls',
#  "Hershey 's",
#  'William “ Rick ” Singer.Former Wynn Resorts',
#  'Boston-based',
#  'Jan Strupczewski',
#  'Gap . Inc.',
#  'UN Climate Change Conference of the Parties',
#  'FTSE',
#  'Danny Meyer',
#  'tionwide',
#  'Chromecast',
#  'Ed Miliband',
#  'Manchester',
#  'Chainalysis',
#  'Yahoo Finance Plus',
#  'Gefen.You',
#  'positive.Jerry Howard',
#  'Leland Miller',
#  'Cashay MyPillow',
#  'Greg Abbott',
#  'IEA',
#  'GettyThat',
#  'Sky Perfect JSAT Holdings',
#  'Mike Loewengart',
#  ...}

# %%
NERlist = list(NERnorm)

# %%
ner = []

# %%
with open("yahoo_finance_marked_df.csv","w") as file:
    writer = csv.writer(file)
    writer.writerow(NERlist)

# %%
x = pd.read_csv('yahoo_finance_marked_df.csv')

# %%
x
# Out:
# Empty DataFrame
# Columns: [Naeem Aslam, Sorare, Aston Martin DB4 GT Zagato Coupe, Jacob Frey., Bruces, Avastin, Naked Brand Group, Secret Service, Transportation Security Administration, Craig-Hallum, BNB Cash, October.Mark Wahlberg, LCpl Hunter Clark, Q & A go, level.Exxon Mobil, Esther Choo, Bremmer, Do Kwon, dollars'Healthcare, Kristoffer Kjær Lomholt, Valencia, Build it Back Better, Chipotle Mexican Grill, Glimmer of hope'Grayscale, Kelton J. Cochran, John McCain, Stemmle, Switzerland-based, Qdoba, Ammann, Ashish Jha, rules.Sheila Bair, Department for Education, Natasha Bhuyan., SBEC, Sears Home Services, Oliver Daemen, Daily Beast, Sens, Coinbase Cloud, service.Sheila Bair, Salvador, FTSE 250, LabCorp, Canadian, Del Rio, Jovan Vavic, LUNAtics, Bowery Hotel, Romney, Wharton, Toby Chopra, Ipsos, Jared, Gumbinger, Jason Redmond, Shiba Inu, Embry-Riddle, UAL, Chainanalysis, JTC, Zacks.com, Mickie, Record App Activity, The 73rd Primetime Emmy Awards, DEO, U.S.How, Philippines, Diane Jaffee, Kernan., Steve Mnuchin, Woodstock of Capitalism post-Buffett, Business Roundtable, Smead Capital Management, Banza Pizza, Cleveland-Marshall College of Law, Eric, United States.Aero Engine Corp, Laurence Tribe, How to Value a Business, Nikkei Asia, PATRICK T. FALLON, Binky Chadha, Yahoo Finance US, Sling TV, SAN FRANCISCO, Refinitiv, JP Morgan Chase & Co., PT.Alexandra, Yahoo FinanceBanks, Benzinga.com, Switzerland, eBay, Benchmark European, Jubilee Vape & Smoke Inc., DCEP, Ida-like, YouTubeAlexis Keenan, Governor Baker, UPS, ...]
# Index: []
#
# [0 rows x 12648 columns]

# %%
array = []

# %%
#binary embedding
with open("yahoo_finance_marked_df.csv","a") as file:
        for j in range(len(df['news'])):
            for word in NERlist:
                a = 0
                for line in df['news'][j]:
                    if word in line:
                        a = (a + 1)/(a + 1)
                    else:
                        a =a + 0
                array.append(a)
            writer = csv.writer(file)
            writer.writerow(array)
            #print(array)   
            array.clear()
